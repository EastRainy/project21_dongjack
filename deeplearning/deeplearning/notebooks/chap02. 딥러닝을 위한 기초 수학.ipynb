# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
'''
문제] x의 범위가 -8 부터 +8 인 경우의 시그모이드 함수 그래프를 그리는 코드를 작성하세요.
'''

# %%
x = np.arange(-8, 8.1, 0.1)
y = 1 / (1 + np.e ** (-x))

plt.plot(x, y)
plt.show()
