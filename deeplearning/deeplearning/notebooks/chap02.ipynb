# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
np.e
# Out:
# 2.718281828459045

# %%
x = np.arange(-8,8.1)
y = 1/(1+np.e**(-x))

# %%
plt.plot(x,y)
plt.show()
